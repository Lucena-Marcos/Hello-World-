# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucena-Marcos/Hello-World-/blob/main/DeepLearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from IPython.display import Image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-25759522-feff-46b6-a677-95359ffc610d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25759522-feff-46b6-a677-95359ffc610d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 12499.jpg to 12499.jpg

# %%
Image("12499.jpg",width =1200)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b040eb1b-ca64-46cd-8fbe-582f98797de2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b040eb1b-ca64-46cd-8fbe-582f98797de2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 12498.jpg to 12498.jpg

# %%
Image("12498.jpg",width=1200)

# %%
import tensorflow as tf
print("versão do TensorFlow:", tf.__version__)
# Out:
# versão do TensorFlow: 2.4.1

# %%
import keras as k
print("versão do Keras:",k.__version__)
# Out:
# versão do Keras: 2.4.3

# %%
# Imports
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
# Inicializando a Rede Neural Convolucional
classifier = Sequential()

# %%
# Passo 1 - Primeira Camada de Convolução
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

# %%
# Passo 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %%
# Adicionando a Segunda Camada de Convolução
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))

# %%
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# %%
# Passo 3 - Flattening
classifier.add(Flatten())

# %%
# Passo 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

# %%
# Compilando a rede
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Criando os objetos train_datagen e validation_datagen com as regras de pré-processamento das imagens
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale = 1./255)

# %%
uploaded = files.upload()

# %%
# Pré-processamento das imagens de treino e validação
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/DeepLearning',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 9461 images belonging to 1 classes.
